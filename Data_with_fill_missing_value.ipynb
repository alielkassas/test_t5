# %% [markdown]
# <a href="https://colab.research.google.com/github/Nawaf9997/test_t5/blob/main/Data_with_fill_missing_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Expanded_data_with_more_features.csv')
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0           none             married     regularly          yes         3.0
# 1            NaN             married     sometimes          yes         0.0
# 2           none              single     sometimes          yes         4.0
# 3           none             married         never           no         1.0
# 4           none             married     sometimes          yes         0.0
# ...          ...                 ...           ...          ...         ...
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 3.5+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df["EthnicGroup"].mode() #if they don't belong to any existing group that's mean they belong to 'Other' Gropups
# Out:
# 0    group C
# Name: EthnicGroup, dtype: object

# %%
df["EthnicGroup"].fillna("Other",inplace=True)

# %%
df["ParentEduc"].mode() # if they don't have any existing Education that's mean they belong to 'Other'parent Education
# Out:
# 0    some college
# Name: ParentEduc, dtype: object

# %%
df["ParentEduc"].fillna("Other",inplace=True)

# %%
df["TestPrep"].mode()
# Out:
# 0    none
# Name: TestPrep, dtype: object

# %%
df["TestPrep"].fillna("Unknow",inplace=True)

# %%
df["ParentMaritalStatus"].mode()
# Out:
# 0    married
# Name: ParentMaritalStatus, dtype: object

# %%
df["ParentMaritalStatus"].fillna("married",inplace=True)

# %%
df["PracticeSport"].mode()
# Out:
# 0    sometimes
# Name: PracticeSport, dtype: object

# %%
df["PracticeSport"].fillna("sometimes",inplace=True)

# %%
df["IsFirstChild"].mode()
# Out:
# 0    yes
# Name: IsFirstChild, dtype: object

# %%
df["IsFirstChild"].fillna("yes",inplace=True)

# %%
df['NrSiblings'].mode()
# Out:
# 0    1.0
# Name: NrSiblings, dtype: float64

# %%
df['NrSiblings'] = df['NrSiblings'].astype(pd.Int64Dtype())
#change type of Number of Siblings to int so we can see the max , min , mean and count
#let's describe df

# %%
df['NrSiblings'].mode()
# Out:
# 0    1
# Name: NrSiblings, dtype: Int64

# %%
df['NrSiblings'].fillna(2,inplace=True)
#we can see that the number of Siblings mean is 2 so :

# %%
df['TransportMeans'].mode()
# Out:
# 0    school_bus
# Name: TransportMeans, dtype: object

# %%
df['TransportMeans'].fillna("Public",inplace=True)

# %%
df["WklyStudyHours"].mode()
# Out:
# 0    5 - 10
# Name: WklyStudyHours, dtype: object

# %%
df["WklyStudyHours"].fillna(5-10,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Gender                 0
# EthnicGroup            0
# ParentEduc             0
# LunchType              0
# TestPrep               0
# ParentMaritalStatus    0
# PracticeSport          0
# IsFirstChild           0
# NrSiblings             0
# TransportMeans         0
# WklyStudyHours         0
# MathScore              0
# ReadingScore           0
# WritingScore           0
# dtype: int64

# %%
df.sample(20)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 4096          321  female     group C               Other      standard
# 23874         441  female     group B    some high school  free/reduced
# 11882         601    male     group B        some college      standard
# 8655          162  female     group B    some high school  free/reduced
# 27759         611  female     group C  associate's degree      standard
# 4665          921  female     group D     master's degree  free/reduced
# 24237         832    male     group B        some college      standard
# 6994          389    male     group E         high school  free/reduced
# 8285          771    male     group C               Other      standard
# 15564         530  female     group D   bachelor's degree      standard
# 24762         389  female     group B    some high school  free/reduced
# 23444         984    male     group D   bachelor's degree      standard
# 5430          725    male     group E    some high school      standard
# 11802         514    male     group E   bachelor's degree      standard
# 26183         922  female     group C     master's degree  free/reduced
# 4152          383  female     group D  associate's degree      standard
# 15659         630    male     group C         high school      standard
# 27476         302    male     group B         high school      standard
# 12050         778    male     group C  associate's degree  free/reduced
# 6535          896    male      Other)        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 4096   completed              single     regularly          yes           1
# 23874       none            divorced     sometimes          yes           2
# 11882       none              single         never           no           4
# 8655        none              single     regularly           no           3
# 27759       none             married     sometimes          yes           1
# 4665        none              single         never           no           3
# 24237       none              single     regularly          yes           5
# 6994        none             married     regularly          yes           2
# 8285        none            divorced     regularly          yes           0
# 15564       none             married         never          yes           2
# 24762       none              single     regularly          yes           0
# 23444       none             married     regularly           no           1
# 5430        none              single         never          yes           4
# 11802       none              single     sometimes           no           4
# 26183  completed             married     sometimes          yes           4
# 4152   completed             married     regularly          yes           1
# 15659       none             married         never          yes           3
# 27476       none            divorced     sometimes          yes           1
# 12050  completed              single     sometimes          yes           3
# 6535        none             married     sometimes          yes           3
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 4096      school_bus           > 10         84            85            87
# 23874     school_bus            < 5         43            51            50
# 11882     school_bus         5 - 10         84            84            75
# 8655         private           > 10         40            57            54
# 27759     school_bus           > 10         71            80            77
# 4665         private         5 - 10         60            67            70
# 24237     school_bus         5 - 10         82            68            69
# 6994         private            < 5         76            66            69
# 8285      school_bus         5 - 10         71            65            64
# 15564        private         5 - 10         40            49            51
# 24762     school_bus            < 5         60            77            71
# 23444     school_bus         5 - 10         79            78            70
# 5430      school_bus         5 - 10         70            64            55
# 11802     school_bus         5 - 10         78            65            63
# 26183        private         5 - 10         78            82            84
# 4152      school_bus         5 - 10         77            81            83
# 15659        private         5 - 10         82            82            80
# 27476        private         5 - 10         76            74            62
# 12050     school_bus         5 - 10         85            77            80
# 6535      school_bus             -5         65            70            67

# %%
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female      Other)   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard     none
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes           3     school_bus
# 1             married     sometimes          yes           0         Public
# 2              single     sometimes          yes           4     school_bus
# 3             married         never           no           1         Public
# 4             married     sometimes          yes           0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# 1         5 - 10         69            90            88
# 2            < 5         87            93            91
# 3         5 - 10         45            56            42
# 4         5 - 10         76            78            75

# %%
df.tail()
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female      Other)         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 30636       none              single     sometimes           no           2
# 30637       none              single     regularly           no           1
# 30638  completed             married     sometimes           no           1
# 30639  completed             married     regularly           no           3
# 30640       none             married         never           no           1
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58

# %%
df.describe()
# Out:
#          Unnamed: 0  NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000     30641.0  30641.000000  30641.000000  30641.000000
# mean     499.556607    2.138409     66.558402     69.377533     68.418622
# std      288.747894    1.420707     15.361616     14.758952     15.443525
# min        0.000000         0.0      0.000000     10.000000      4.000000
# 25%      249.000000         1.0     56.000000     59.000000     58.000000
# 50%      500.000000         2.0     67.000000     70.000000     69.000000
# 75%      750.000000         3.0     78.000000     80.000000     79.000000
# max      999.000000         7.0    100.000000    100.000000    100.000000

# %%
#Do you think the parent Education might effect in the students score?

# Let's see :)

df1=df.groupby("ParentEduc").agg({"MathScore": "mean","ReadingScore":"mean","WritingScore":"mean"} , inplace=True)
df1
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# Other               66.645528     69.225474     68.295935
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
# now we can do the heatmap :

sns.heatmap(df1 , annot= True)
plt.title("how parent's Education effect on student's score")
plt.show()

# %% [markdown]
# **Now we can see the correlations bettwen the parents who have master degree the students Scores.**
#
# **So we can findout : That the student's who have High scores there parents have master dgree.**

# %%
# Import the necessary module.
from google.colab import files

# Download the file.
files.download('/content/Expanded_data_with_more_features.csv')

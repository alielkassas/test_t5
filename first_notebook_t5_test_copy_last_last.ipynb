# %% [markdown]
# <a href="https://colab.research.google.com/github/alielkassas/test_t5/blob/main/first_notebook_t5_test_copy_last_last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    x = 2
    print("hello")
# Out:
# Streaming output truncated to the last 5000 lines.
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# **bold**
# *italic*
# **text**
# [my website](https://www.linkedin.com/feed/)
#
#
# `print("hello")`
#
# - first section about colab
# - Second abojgihjcg
#
#
# 1. first
# 2. second
#
# ![1721040490798.jpg](data:image/jpeg;base64,...)

# %%
x = 2
print(x)
# Out:
# 2
